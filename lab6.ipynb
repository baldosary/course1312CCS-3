# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 06 — Strings
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To Create and Use String in Programming
# 2. To access characters within a string using index operators.
# 3. To use various in-built functions of strings

# %% [markdown]
# ### <span style="color:#5C6BC0"> Instructions: </span>
# 1. The Lab manual is based upon the Lecture PPTs 12.
# 2. It is better to review them once.
# 3. The activity can also be split and practice in two sessions as per the beneficiaries interest.

# %% [markdown]
# ## <span style="color:#283593; font-weight:bold;">Lab Exercises — Practice Section</span>

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
# Write a program to prompt users to enter a string and find its length.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a string: Intro to Programming
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# Length of the string: 20
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
# Write a program to traverse every second-string character using a for loop.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a string: Programming
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# P o r m i g
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
# Write a program to traverse every second-string character using a while loop.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a string: Programming
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# P o r m i g
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
# Write a program to prompt a user to enter a string and check whether it is a palindrome or not. [e.g., madam, abba]
# <br>
# <br>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 5
# </span>
# Write a program in Python that takes two words and returns a new word that is a mirror
# text.
# E.g. [First word: Python, Second word: Strong, Return word: PythonStrongStrongPython]
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter first word: Learn <br>
# Enter second word: Python <br>
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# Mirror word: LearnPythonPythonLearn
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 6
# </span>
# Write a Python program that takes a word [abbbabbaaa] as an input and returns the number of ‘b’ in the word.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a word: abbbabbaaa
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# Number of 'b' characters: 5
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 7
# </span>
# Write a program in Python that takes a word from the user and returns the word with all the vowels capitalized.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a word: education
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# EdUcAtIOn
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 8
# </span>
# Write a Python program that takes two words from the user and displays a message “yes reverse”, if the second word is reverse of the first word.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter first word: python  <br>
# Enter second word: nohtyp  <br>
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# yes reverse
# </span>
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter first word: data  <br>
# Enter second word: date  <br>
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# not reverse
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 9
# </span>
# Write a python program that takes a word from the user and removes all the vowels {a, e, i, o, u} and returns the word. E.g., If the entered word is abceiodeuf, the returned word should be bcdf.
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a word: education
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <br>
# <span style="font-size:13px; font-family:monospace;">
# dctn

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 10</span>
#
# Write a Python program and enter a word with white space characters and use the `strip()` function to remove white space characters and return the entered string.
#
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input:
# </span>
#
# Enter a word:&nbsp;&nbsp;&nbsp;Intro to Programming
#
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Output:
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Intro to Programming
# </span>

# %%
### Student Code

## Write your answer here
