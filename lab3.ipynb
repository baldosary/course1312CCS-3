# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 03 — Python program to demonstrate the use of conditional statements
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To use Conditional Statements in Python
# 2. To use if Conditional Statements in Python
# 3. To use if...else Conditional Statements in Python
# 4. To use elif and nested Conditional Statements in Python
# 5. To use the ternary operator in Python

# %% [markdown]
# ## <span style="color:#5C6BC0"> Conditional Statement in Python </span>
#
# Conditional statements in Python are used to execute certain blocks of code based on specific conditions. These statements help control the flow of a program, making it behave differently in different situations.

# %% [markdown]
# ### <span style="color:#5C6BC0"> if Conditional Statement in Python </span>
# **If statement** is the simplest form of a conditional statement. It executes a block of code if the given condition is true.

# %%
age = 20
if age >= 18:
    print("Eligible for driving License.")
# Out:
# Eligible for driving License.

# %% [markdown]
# ### <span style="color:#5C6BC0"> If else Conditional Statements in Python </span>
# It allows us to specify a block of code that will execute if the condition(s) associated with an if or elif statement evaluates to False. Else block provides a way to handle all other cases that don't meet the specified conditions.

# %%
age = 10
if age <= 12:
    print("Travel for free.")
else:
    print("Pay for ticket.")
# Out:
# Travel for free.

# %% [markdown]
# ### <span style="color:#5C6BC0"> elif Statement </span>
# elif statement in Python stands for "else if." It allows us to check multiple conditions , providing a way to execute different blocks of code based on which condition is true. Using elif statements makes our code more readable and efficient by eliminating the need for multiple nested if
# statements.

# %%
age = 25
if age <= 12:
    print("Child.")
elif age <= 19:
    print("Teenager.")
elif age <= 35:
    print("Young adult.")
else:
    print("Adult.")
# Out:
# Young adult.

# %% [markdown]
# ### <span style="color:#5C6BC0"> Nested if..else Conditional Statements in Python </span>
# Nested if..else means an if-else statement inside another if statement. We can use nested if statements to check conditions within conditions.

# %%
age = 70
is_member = True
if age >= 60:
    if is_member:
        print("30% senior discount!")
    else:
        print("20% senior discount.")
else:
    print("Not eligible")
# Out:
# 30% senior discount!

# %% [markdown]
# ### <span style="color:#5C6BC0"> Ternary Conditional Statement in Python </span>
# A ternary conditional statement is a compact way to write an if-else condition in a single line. It’s sometimes called a "conditional expression."

# %%
# Assign a value based on a condition
age = 20
s = "Adult" if age >= 18 else "Minor"
print(s)
# Out:
# Adult

# %% [markdown]
# ## <span style="color:#283593; font-weight:bold;">Lab Exercises — Practice Section</span>

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
#
# Write a program to input a year and check whether it is a leap or not.
#
# <b>Assume:</b> A year is a leap year if: It is divisible by 4 and Not divisible by 100, Unless it is also divisible by 400.
#
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input 1
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Enter a year: 2000
# </span>
#
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Output
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Leap Year
# </span>
#
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input 2
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Enter a year: 2023
# </span>
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Output 2
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Not a Leap Year
# </span>
#
# <br>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
#
# Write a program to calculate the internet browsing bill based on the following rates: <br>
# 1 hour = 20 SAR <br>
# 30 minutes (0.5 hour) = 10 SAR <br>
# Unlimited hours in a day = 100 SAR <br>
#
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input 1:
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Number of hours: 2
# </span>
#
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Output 1:
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Total Bill = 40 SAR
# </span>
#
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input 2:
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Number of hours: 6
# </span>
# <br>
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Output 2:
# </span>
#
# <span style="font-size:13px; font-family:monospace;">
# Total Bill = 100 SAR
# </span>
#
# <br>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
# Write a program to calculate the square of only those numbers whose least significant digit is 5.
#
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter the number: 25
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <span style="font-size:13px; font-family:monospace;">
# Square 25*25 = 625.
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
# Write a program to enter a number and tell whether it is odd or even.
#
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter a number: 1024
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <span style="font-size:13px; font-family:monospace;">
# Even
# </span>

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 5
# </span>
# Write a program that generates the Fibonacci sequence up-to a given number of terms.
#
# <br>
# <br>
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
# Example Input: </span>
# Enter number of terms: 8
# <br>
# </span>
# <span style="color:#37474F; font-size:14px; font-weight:bold;"> Example Output </span>
# <span style="font-size:13px; font-family:monospace;">
# Fibonacci Sequence:
# 0 1 1 2 3 5 8 13
# </span>

# %%
### Student Code

## Write your answer here
