# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 11 — Set and Dictionary Data Structure
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To Create and Use a Set and Dictionary Data Structure
# 2. Access elements from the Dictionary
# 3. Apply various Operations on the Set and Dictionary elements.

# %% [markdown]
# ### <span style="color:#5C6BC0"> Instructions: </span>
#
# 1. The Lab manual is based upon the Lecture PPTs 17 and 18.
# 2. Please review it once before attempting the problems in the manual.

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
#
# Write a program that checks if one set is a subset of another.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
#
# Create a function that merges multiple sets into one and returns the result.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
#
# Write a program that finds the elements in either of the sets, but not when two sets are given.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
#
# Write a function that swaps keys and values in a dictionary.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 5
# </span>
#
# Write a function that merges two dictionaries. If they have the same keys, sum up their values.

# %%
### Student Code

## Write your answer here
