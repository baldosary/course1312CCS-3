# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 07 — Functions
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To Create and Use Functions in Programming
# 2. How to pass parameters in function.
# 3. How to call function with and without parameters.

# %% [markdown]
# ### <span style="color:#5C6BC0"> Instructions: </span>
# 1. The Lab manual is based upon the Lecture PPTs 13
# 2. Please review it once before attempting the problems in the manual.

# %% [markdown]
# ## <span style="color:#283593; font-weight:bold;">Lab Exercises — Practice Section</span>

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
# Write a Python function to calculate the area of a circle.
#
# The formula for the area of a circle is:
#
# $$
# \text{Area} = \pi r^2
# $$

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
#
# Write a Python function:
#
# calc_distance(x1, y1, x2, y2)
#
# to calculate the distance between two points:
#
# - Point 1 → (x1, y1)
# - Point 2 → (x2, y2)
#
# The formula for calculating distance is:
#
# $$
# \text{Distance} = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}
# $$

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
#
# Write a function to traverse every second-string character of the entered string.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
#
# A four-digit integer is entered through the keyboard. Write a function to calculate the sum
# of the digits.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 5
# </span>
#
# Write a Python function that takes a word from the user, removes all the vowels {a, e, i, o,
# u}, and returns the word. E.g., If the entered word is abceiodeuf, the returned word should
# be bcdf.

# %%
### Student Code

## Write your answer here
