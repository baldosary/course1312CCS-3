# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 08 — Functions (Part-2)
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To Create and Use Functions in Programming
# 2. How to pass parameters in the function.
# 3. Use of Math and other library functions.
# 4. How to call a function with and without parameters.

# %% [markdown]
# ### <span style="color:#5C6BC0"> Instructions: </span>
# 1. The Lab manual is based upon the Lecture PPTs 13
# 2. Please review it once before attempting the problems in the manual.

# %% [markdown]
# ## <span style="color:#283593; font-weight:bold;">Lab Exercises — Practice Section</span>

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
#
# A positive integer is entered through the keyboard. Write a function
# `factors(num)` to obtain the factors of the given numbers.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
#
# Write a Python function to calculate compound interest for a principal amount of SAR 10000 at a rate of interest (profit) of 5%, assuming that the amount is deposited for 7 years.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
#
# Write a Python function to convert degrees entered via the keyboard into radians.
#
# The formula for converting degrees to radians is:
#
# $$
# \text{Radians} = \text{Degrees} \times \frac{\pi}{180}
# $$

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
#
# Write a Python function to compute the factorial of a number using the math library and without using the math library.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 5
# </span>
#
# Write a Python function to compute the hypotenuse of a right triangle. The base and perpendicular are entered through the keyboard.
# Use the Pythagorean Theorem:
#
# $$
# \text{Hypotenuse} = \sqrt{(\text{base})^2 + (\text{perpendicular})^2}
# $$

# %%
### Student Code

## Write your answer here
