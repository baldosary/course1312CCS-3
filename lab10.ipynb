# %% [markdown]
# <span style="color:#0A3D62; font-size:28px; font-weight:bold;">
# Introduction to Programming
# </span>
#
# <br>
#
# <span style="color:#3C6382; font-size:20px;">
# Course Code: 1312CCS-3
# </span>
#
# <br>
#
# <span style="color:#82CCDD; font-size:20px; font-weight:bold;">
# Lab 10 — Tuple Data Structure
# </span>

# %% [markdown]
# ## <span style="color:#5C6BC0">Objectives</span>
#
# By the end of this lab, you should be able to:
#
# 1. To Create and Use a Tuple Data structure
# 2. Access elements from the tuples
# 3. Apply various Operations on the accessed elements.

# %% [markdown]
# ### <span style="color:#5C6BC0"> Instructions: </span>
#
# 1. The Lab manual is based upon the Lecture PPTs 16.
# 2. Please review it once before attempting the problems in the
# manual.

# %% [markdown]
# ## <span style="color:#283593; font-weight:bold;">Lab Exercises — Practice Section</span>

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 1
# </span>
# Write a program to create a function sum_all() to accept a variable number of arguments and display the sum of all the elements present in it.
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
#
#
# Example: </span>
#
# **Input:**
# sum_all(2, 4, 6)
#
# **Output:**
# 12

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 2
# </span>
#
# Consider an example of a tuple as `T = (1, 3, 2, 4, 6, 5)`. Write a program to store numbers present at odd indices into a new tuple.

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 3
# </span>
# Write a function which takes a tuple as a parameter and returns a new tuple as the output, where every other element of the input tuple is copied, starting from the first one.
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
#
# Example: </span>
#
# **Input:**
# T=(‘Hello’, ‘Are’, ‘you’, ‘Loving’, ‘Python?’)
#
# **Output:**
# Output_Tuple = ('Hello’, ‘you’, ‘Python?’)

# %%
### Student Code

## Write your answer here

# %% [markdown]
# ### <span style="color:#00838F; font-weight:bold;">Exercise 4
# </span>
#
# Write a program to create a list of tuples with numbers and their cubes.
#
# <span style="color:#37474F; font-size:14px; font-weight:bold;">
#
# Example: </span>
#
# **Input:**
# [1, 2, 3]
#
# **Output:**
# [(1, 1), (2, 8), (3, 27)]

# %%
### Student Code

## Write your answer here
